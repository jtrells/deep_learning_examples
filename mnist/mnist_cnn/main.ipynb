# %%
import tensorflow as tf

from models.mnist_model import MnistModel
from trainers.mnist_trainer import MnistTrainer
from utils.logger import Logger
from utils.mnist_loader import MnistDataLoader

import numpy as np

# %%
config = {
    'batch_size': 64,
    'num_epochs': 10,
    'eval_batch_size': 64,
    'eval_frequency': 100,
    'work_dir': 'D://_dev//tensorflow//data',
    'source_url': 'http://yann.lecun.com/exdb/mnist/',
    'image_size': 28,
    'num_channels': 1,
    'pixel_depth': 255,
    'validation_size': 5000,
    'num_labels': 10, # [0..9]
    'seed': 66478,
    'max_to_keep': 1,
    'summary_dir': 'D://_dev//tensorflow//summaries//mnist',
    'checkpoint_dir': 'D://_dev//tensorflow//checkpoints//mnist',
}

# %%
def main():
    sess = tf.Session()
    data = MnistDataLoader.get_data(config)
    model = MnistModel(config)
    logger = Logger(sess, config)
    trainer = MnistTrainer(sess, model, data, config, logger)
    trainer.train()
    trainer.eval_test()

# %%
main()
# Out:
# Extracting D://_dev//tensorflow//data\train-images-idx3-ubyte.gz
# Extracting D://_dev//tensorflow//data\train-labels-idx1-ubyte.gz
# Extracting D://_dev//tensorflow//data\t10k-images-idx3-ubyte.gz
# Extracting D://_dev//tensorflow//data\t10k-labels-idx1-ubyte.gz
# Step 0 (epoch 0.00),
# Minibatch loss: 12.054, learning rate: 0.010000
# Minibatch error: 85.9%
# Validation error: 84.6%
# Step 100 (epoch 0.12),
# Minibatch loss: 3.303, learning rate: 0.010000
# Minibatch error: 6.2%
# Validation error: 7.4%
# Step 200 (epoch 0.23),
# Minibatch loss: 3.448, learning rate: 0.010000
# Minibatch error: 9.4%
# Validation error: 4.6%
# Step 300 (epoch 0.35),
# Minibatch loss: 3.319, learning rate: 0.010000
# Minibatch error: 3.1%
# Validation error: 3.2%
# Step 400 (epoch 0.47),
# Minibatch loss: 3.234, learning rate: 0.010000
# Minibatch error: 7.8%
# Validation error: 2.6%
# Step 500 (epoch 0.58),
# Minibatch loss: 3.323, learning rate: 0.010000
# Minibatch error: 6.2%
# Validation error: 2.6%
# Step 600 (epoch 0.70),
# Minibatch loss: 3.141, learning rate: 0.010000
# Minibatch error: 3.1%
# Validation error: 2.3%
# Step 700 (epoch 0.81),
# Minibatch loss: 2.959, learning rate: 0.010000
# Minibatch error: 1.6%
# Validation error: 2.2%
# Step 800 (epoch 0.93),
# Minibatch loss: 3.104, learning rate: 0.010000
# Minibatch error: 6.2%
# Validation error: 2.0%
# Saving model...
# Model saved
# Step 0 (epoch 0.00),
# Minibatch loss: 3.057, learning rate: 0.009500
# Minibatch error: 1.6%
# Validation error: 2.0%
# Step 100 (epoch 0.12),
# Minibatch loss: 2.901, learning rate: 0.009500
# Minibatch error: 0.0%
# Validation error: 1.7%
# Step 200 (epoch 0.23),
# Minibatch loss: 2.983, learning rate: 0.009500
# Minibatch error: 3.1%
# Validation error: 1.8%
# Step 300 (epoch 0.35),
# Minibatch loss: 2.936, learning rate: 0.009500
# Minibatch error: 3.1%
# Validation error: 1.4%
# Step 400 (epoch 0.47),
# Minibatch loss: 2.964, learning rate: 0.009500
# Minibatch error: 1.6%
# Validation error: 1.3%
# Step 500 (epoch 0.58),
# Minibatch loss: 2.913, learning rate: 0.009500
# Minibatch error: 4.7%
# Validation error: 1.4%
# Step 600 (epoch 0.70),
# Minibatch loss: 2.921, learning rate: 0.009500
# Minibatch error: 1.6%
# Validation error: 1.4%
# Step 700 (epoch 0.81),
# Minibatch loss: 2.702, learning rate: 0.009500
# Minibatch error: 1.6%
# Validation error: 1.4%
# Step 800 (epoch 0.93),
# Minibatch loss: 2.711, learning rate: 0.009500
# Minibatch error: 1.6%
# Validation error: 1.7%
# Saving model...
# Model saved
# Step 0 (epoch 0.00),
# Minibatch loss: 2.666, learning rate: 0.009025
# Minibatch error: 3.1%
# Validation error: 1.5%
# Step 100 (epoch 0.12),
# Minibatch loss: 2.710, learning rate: 0.009025
# Minibatch error: 0.0%
# Validation error: 1.3%
# Step 200 (epoch 0.23),
# Minibatch loss: 2.832, learning rate: 0.009025
# Minibatch error: 4.7%
# Validation error: 1.4%
# Step 300 (epoch 0.35),
# Minibatch loss: 2.615, learning rate: 0.009025
# Minibatch error: 6.2%
# Validation error: 1.2%
# Step 400 (epoch 0.47),
# Minibatch loss: 2.651, learning rate: 0.009025
# Minibatch error: 4.7%
# Validation error: 1.2%
# Step 500 (epoch 0.58),
# Minibatch loss: 2.623, learning rate: 0.009025
# Minibatch error: 4.7%
# Validation error: 1.1%
# Step 600 (epoch 0.70),
# Minibatch loss: 2.685, learning rate: 0.009025
# Minibatch error: 3.1%
# Validation error: 1.2%
# Step 700 (epoch 0.81),
# Minibatch loss: 2.500, learning rate: 0.009025
# Minibatch error: 1.6%
# Validation error: 1.3%
# Step 800 (epoch 0.93),
# Minibatch loss: 2.502, learning rate: 0.009025
# Minibatch error: 1.6%
# Validation error: 1.4%
# Saving model...
# Model saved
# Step 0 (epoch 0.00),
# Minibatch loss: 2.515, learning rate: 0.009025
# Minibatch error: 3.1%
# Validation error: 1.2%
# Step 100 (epoch 0.12),
# Minibatch loss: 2.473, learning rate: 0.008574
# Minibatch error: 1.6%
# Validation error: 1.1%
# Step 200 (epoch 0.23),
# Minibatch loss: 2.557, learning rate: 0.008574
# Minibatch error: 3.1%
# Validation error: 1.1%
# Step 300 (epoch 0.35),
# Minibatch loss: 2.416, learning rate: 0.008574
# Minibatch error: 0.0%
# Validation error: 1.1%
# Step 400 (epoch 0.47),
# Minibatch loss: 2.402, learning rate: 0.008574
# Minibatch error: 3.1%
# Validation error: 1.1%
# Step 500 (epoch 0.58),
# Minibatch loss: 2.492, learning rate: 0.008574
# Minibatch error: 1.6%
# Validation error: 1.0%
# Step 600 (epoch 0.70),
# Minibatch loss: 2.493, learning rate: 0.008574
# Minibatch error: 1.6%
# Validation error: 1.0%
# Step 700 (epoch 0.81),
# Minibatch loss: 2.312, learning rate: 0.008574
# Minibatch error: 0.0%
# Validation error: 1.0%
# Step 800 (epoch 0.93),
# Minibatch loss: 2.302, learning rate: 0.008574
# Minibatch error: 3.1%
# Validation error: 1.2%
# Saving model...
# Model saved
# Step 0 (epoch 0.00),
# Minibatch loss: 2.336, learning rate: 0.008574
# Minibatch error: 1.6%
# Validation error: 1.2%
# Step 100 (epoch 0.12),
# Minibatch loss: 2.296, learning rate: 0.008145
# Minibatch error: 1.6%
# Validation error: 1.1%
# Step 200 (epoch 0.23),
# Minibatch loss: 2.314, learning rate: 0.008145
# Minibatch error: 3.1%
# Validation error: 1.0%
# Step 300 (epoch 0.35),
# Minibatch loss: 2.228, learning rate: 0.008145
# Minibatch error: 1.6%
# Validation error: 1.0%
# Step 400 (epoch 0.47),
# Minibatch loss: 2.239, learning rate: 0.008145
# Minibatch error: 1.6%
# Validation error: 1.1%
# Step 500 (epoch 0.58),
# Minibatch loss: 2.354, learning rate: 0.008145
# Minibatch error: 6.2%
# Validation error: 0.9%
# Step 600 (epoch 0.70),
# Minibatch loss: 2.327, learning rate: 0.008145
# Minibatch error: 1.6%
# Validation error: 0.9%
# Step 700 (epoch 0.81),
# Minibatch loss: 2.163, learning rate: 0.008145
# Minibatch error: 0.0%
# Validation error: 0.9%
# Step 800 (epoch 0.93),
# Minibatch loss: 2.148, learning rate: 0.008145
# Minibatch error: 0.0%
# Validation error: 1.1%
# Saving model...
# Model saved
# Step 0 (epoch 0.00),
# Minibatch loss: 2.142, learning rate: 0.008145
# Minibatch error: 0.0%
# Validation error: 1.0%
# Step 100 (epoch 0.12),
# Minibatch loss: 2.141, learning rate: 0.007738
# Minibatch error: 3.1%
# Validation error: 1.1%
# Step 200 (epoch 0.23),
# Minibatch loss: 2.182, learning rate: 0.007738
# Minibatch error: 1.6%
# Validation error: 1.0%
# Step 300 (epoch 0.35),
# Minibatch loss: 2.078, learning rate: 0.007738
# Minibatch error: 1.6%
# Validation error: 0.9%
# Step 400 (epoch 0.47),
# Minibatch loss: 2.076, learning rate: 0.007738
# Minibatch error: 4.7%
# Validation error: 1.0%
# Step 500 (epoch 0.58),
# Minibatch loss: 2.142, learning rate: 0.007738
# Minibatch error: 3.1%
# Validation error: 0.9%
# Step 600 (epoch 0.70),
# Minibatch loss: 2.148, learning rate: 0.007738
# Minibatch error: 3.1%
# Validation error: 1.1%
# Step 700 (epoch 0.81),
# Minibatch loss: 2.020, learning rate: 0.007738
# Minibatch error: 0.0%
# Validation error: 0.8%
# Step 800 (epoch 0.93),
# Minibatch loss: 2.047, learning rate: 0.007738
# Minibatch error: 1.6%
# Validation error: 1.0%
# Saving model...
# Model saved
# Step 0 (epoch 0.00),
# Minibatch loss: 2.076, learning rate: 0.007738
# Minibatch error: 1.6%
# Validation error: 1.0%
# Step 100 (epoch 0.12),
# Minibatch loss: 1.985, learning rate: 0.007351
# Minibatch error: 0.0%
# Validation error: 1.1%
# Step 200 (epoch 0.23),
# Minibatch loss: 1.978, learning rate: 0.007351
# Minibatch error: 3.1%
# Validation error: 1.0%
# Step 300 (epoch 0.35),
# Minibatch loss: 1.968, learning rate: 0.007351
# Minibatch error: 1.6%
# Validation error: 1.0%
# Step 400 (epoch 0.47),
# Minibatch loss: 1.971, learning rate: 0.007351
# Minibatch error: 3.1%
# Validation error: 1.0%
# Step 500 (epoch 0.58),
# Minibatch loss: 1.993, learning rate: 0.007351
# Minibatch error: 1.6%
# Validation error: 0.7%
# Step 600 (epoch 0.70),
# Minibatch loss: 1.947, learning rate: 0.007351
# Minibatch error: 1.6%
# Validation error: 0.9%
# Step 700 (epoch 0.81),
# Minibatch loss: 1.893, learning rate: 0.007351
# Minibatch error: 0.0%
# Validation error: 0.9%
# Step 800 (epoch 0.93),
# Minibatch loss: 1.921, learning rate: 0.007351
# Minibatch error: 1.6%
# Validation error: 0.9%
# Saving model...
# Model saved
# Step 0 (epoch 0.00),
# Minibatch loss: 1.890, learning rate: 0.007351
# Minibatch error: 0.0%
# Validation error: 1.1%
# Step 100 (epoch 0.12),
# Minibatch loss: 1.879, learning rate: 0.006983
# Minibatch error: 0.0%
# Validation error: 1.1%
# Step 200 (epoch 0.23),
# Minibatch loss: 1.952, learning rate: 0.006983
# Minibatch error: 3.1%
# Validation error: 1.0%
# Step 300 (epoch 0.35),
# Minibatch loss: 1.851, learning rate: 0.006983
# Minibatch error: 0.0%
# Validation error: 0.9%
# Step 400 (epoch 0.47),
# Minibatch loss: 1.866, learning rate: 0.006983
# Minibatch error: 3.1%
# Validation error: 0.9%
# Step 500 (epoch 0.58),
# Minibatch loss: 1.867, learning rate: 0.006983
# Minibatch error: 3.1%
# Validation error: 0.9%
# Step 600 (epoch 0.70),
# Minibatch loss: 1.969, learning rate: 0.006983
# Minibatch error: 1.6%
# Validation error: 1.0%
# Step 700 (epoch 0.81),
# Minibatch loss: 1.779, learning rate: 0.006983
# Minibatch error: 0.0%
# Validation error: 0.9%
# Step 800 (epoch 0.93),
# Minibatch loss: 1.784, learning rate: 0.006983
# Minibatch error: 0.0%
# Validation error: 0.9%
# Saving model...
# Model saved
# Step 0 (epoch 0.00),
# Minibatch loss: 1.773, learning rate: 0.006983
# Minibatch error: 0.0%
# Validation error: 0.9%
# Step 100 (epoch 0.12),
# Minibatch loss: 1.755, learning rate: 0.006634
# Minibatch error: 0.0%
# Validation error: 1.0%
# Step 200 (epoch 0.23),
# Minibatch loss: 1.752, learning rate: 0.006634
# Minibatch error: 0.0%
# Validation error: 0.9%
# Step 300 (epoch 0.35),
# Minibatch loss: 1.742, learning rate: 0.006634
# Minibatch error: 0.0%
# Validation error: 1.0%
# Step 400 (epoch 0.47),
# Minibatch loss: 1.753, learning rate: 0.006634
# Minibatch error: 0.0%
# Validation error: 1.0%
# Step 500 (epoch 0.58),
# Minibatch loss: 1.770, learning rate: 0.006634
# Minibatch error: 0.0%
# Validation error: 0.8%
# Step 600 (epoch 0.70),
# Minibatch loss: 1.758, learning rate: 0.006634
# Minibatch error: 1.6%
# Validation error: 0.9%
# Step 700 (epoch 0.81),
# Minibatch loss: 1.685, learning rate: 0.006634
# Minibatch error: 0.0%
# Validation error: 0.8%
# Step 800 (epoch 0.93),
# Minibatch loss: 1.674, learning rate: 0.006634
# Minibatch error: 1.6%
# Validation error: 0.9%
# Saving model...
# Model saved
# Step 0 (epoch 0.00),
# Minibatch loss: 1.715, learning rate: 0.006634
# Minibatch error: 0.0%
# Validation error: 0.9%
# Step 100 (epoch 0.12),
# Minibatch loss: 1.671, learning rate: 0.006302
# Minibatch error: 0.0%
# Validation error: 0.9%
# Step 200 (epoch 0.23),
# Minibatch loss: 1.708, learning rate: 0.006302
# Minibatch error: 0.0%
# Validation error: 0.9%
# Step 300 (epoch 0.35),
# Minibatch loss: 1.635, learning rate: 0.006302
# Minibatch error: 0.0%
# Validation error: 0.8%
# Step 400 (epoch 0.47),
# Minibatch loss: 1.641, learning rate: 0.006302
# Minibatch error: 0.0%
# Validation error: 0.9%
# Step 500 (epoch 0.58),
# Minibatch loss: 1.623, learning rate: 0.006302
# Minibatch error: 0.0%
# Validation error: 0.8%
# Step 600 (epoch 0.70),
# Minibatch loss: 1.679, learning rate: 0.006302
# Minibatch error: 3.1%
# Validation error: 0.8%
# Step 700 (epoch 0.81),
# Minibatch loss: 1.594, learning rate: 0.006302
# Minibatch error: 0.0%
# Validation error: 0.8%
# Step 800 (epoch 0.93),
# Minibatch loss: 1.607, learning rate: 0.006302
# Minibatch error: 0.0%
# Validation error: 1.0%
# Saving model...
# Model saved
# Step 0 (epoch 0.00),
# Minibatch loss: 1.614, learning rate: 0.006302
# Minibatch error: 1.6%
# Validation error: 1.0%
# Step 100 (epoch 0.12),
# Minibatch loss: 1.567, learning rate: 0.005987
# Minibatch error: 1.6%
# Validation error: 0.9%
# Step 200 (epoch 0.23),
# Minibatch loss: 1.575, learning rate: 0.005987
# Minibatch error: 1.6%
# Validation error: 0.9%
# Step 300 (epoch 0.35),
# Minibatch loss: 1.550, learning rate: 0.005987
# Minibatch error: 0.0%
# Validation error: 0.9%
# Step 400 (epoch 0.47),
# Minibatch loss: 1.542, learning rate: 0.005987
# Minibatch error: 0.0%
# Validation error: 1.0%
# Step 500 (epoch 0.58),
# Minibatch loss: 1.585, learning rate: 0.005987
# Minibatch error: 1.6%
# Validation error: 0.9%
# Step 600 (epoch 0.70),
# Minibatch loss: 1.703, learning rate: 0.005987
# Minibatch error: 1.6%
# Validation error: 0.9%
# Step 700 (epoch 0.81),
# Minibatch loss: 1.519, learning rate: 0.005987
# Minibatch error: 0.0%
# Validation error: 0.7%
# Step 800 (epoch 0.93),
# Minibatch loss: 1.507, learning rate: 0.005987
# Minibatch error: 0.0%
# Validation error: 0.8%
# Saving model...
# Model saved
# Test error: 0.7%

# %%
sess = tf.Session()
data = MnistDataLoader.get_data(config)
model = MnistModel(config)
# Out:
# Extracting D://_dev//tensorflow//data\train-images-idx3-ubyte.gz
# Extracting D://_dev//tensorflow//data\train-labels-idx1-ubyte.gz
# Extracting D://_dev//tensorflow//data\t10k-images-idx3-ubyte.gz
# Extracting D://_dev//tensorflow//data\t10k-labels-idx1-ubyte.gz

# %%
model.load(sess)

# %%
sess.run(tf.global_variables_initializer())
feed_dict={model.eval_data: data['test_x'][0:64,...], model.is_training: False}
predictions = sess.run(model.eval_prediction, feed_dict)

# %%
predictions
# Out:
# array([[  1.56828179e-03,   1.59118243e-03,   1.18014391e-03,
#           2.05317585e-04,   5.52182365e-03,   9.79473054e-01,
#           1.98715413e-03,   9.70758902e-06,   6.65921252e-03,
#           1.80409849e-03],
#        [  1.45178242e-03,   4.48860257e-04,   1.55101176e-02,
#           6.80669400e-05,   4.10357816e-03,   9.55598533e-01,
#           7.78874569e-03,   2.25243730e-06,   1.34040518e-02,
#           1.62389618e-03],
#        [  2.68116035e-02,   8.30920879e-04,   7.02119293e-03,
#           6.13044365e-04,   1.40360259e-02,   8.20412576e-01,
#           3.04627270e-02,   1.76476715e-05,   6.25091270e-02,
#           3.72851826e-02],
#        [  2.60540959e-03,   3.69820744e-04,   1.47272978e-04,
#           1.46001603e-05,   4.06958116e-03,   9.83076453e-01,
#           8.74088239e-03,   1.26391149e-06,   5.20096510e-04,
#           4.54544293e-04],
#        [  7.88851827e-03,   2.00309255e-03,   1.79177581e-03,
#           1.79997791e-04,   9.34992544e-03,   9.59509611e-01,
#           1.10409381e-02,   1.17634399e-05,   5.57777658e-03,
#           2.64662015e-03],
#        [  1.23717273e-02,   3.36395751e-04,   1.01996008e-02,
#           3.02481145e-04,   9.83725581e-03,   8.56351435e-01,
#           2.25830991e-02,   2.07461453e-05,   3.83404419e-02,
#           4.96568531e-02],
#        [  3.83614749e-03,   2.61588022e-04,   2.45129131e-03,
#           1.15301817e-04,   3.36371846e-02,   9.36557293e-01,
#           1.25852916e-02,   2.20974907e-05,   2.00908119e-03,
#           8.52464605e-03],
#        [  2.75682542e-03,   3.09189723e-04,   9.48371307e-04,
#           5.03458141e-05,   5.50246844e-03,   9.73594725e-01,
#           8.17611907e-03,   5.81203267e-06,   6.37438521e-03,
#           2.28184625e-03],
#        [  1.08185643e-03,   3.33956326e-04,   2.73834891e-03,
#           8.69326777e-06,   2.11995258e-03,   9.70882773e-01,
#           2.18989700e-02,   1.08228005e-06,   4.80258459e-04,
#           4.54055174e-04],
#        [  1.50740112e-03,   6.96755305e-05,   5.57605003e-04,
#           4.51781898e-06,   3.51282838e-03,   9.89602745e-01,
#           2.40913243e-03,   3.00168813e-06,   3.03163106e-04,
#           2.02985620e-03],
#        [  9.69627814e-04,   7.68180325e-05,   3.14618868e-04,
#           1.97281061e-05,   2.09955475e-03,   9.94382858e-01,
#           1.46184093e-03,   1.10654457e-06,   2.64292175e-04,
#           4.09582310e-04],
#        [  2.14955606e-03,   1.73228342e-04,   2.75567384e-03,
#           1.04849742e-05,   8.23519751e-03,   9.71627712e-01,
#           1.02407970e-02,   8.62893285e-06,   2.14065099e-03,
#        [  2.90925824e-03,   2.94472813e-03,   5.84624382e-03,
#           5.14686108e-04,   3.87605838e-02,   8.88734162e-01,
#           1.15400599e-02,   5.58482498e-05,   2.82769874e-02,
#           2.04173941e-02],
#        [  1.88374915e-03,   1.48640058e-04,   2.11791063e-04,
#           2.63405218e-05,   3.07267508e-03,   9.78717804e-01,
#           3.90940672e-03,   8.04530771e-07,   3.58393765e-03,
#           8.44479445e-03],
#        [  4.73609194e-03,   8.41171655e-04,   1.52759603e-03,
#           3.93840710e-05,   1.82138849e-03,   9.78196919e-01,
#           2.12790142e-03,   2.95019913e-06,   1.01265879e-02,
#           5.80075895e-04],
#        [  7.71304825e-03,   6.06359448e-04,   1.40296144e-03,
#           1.41662866e-04,   7.40460027e-03,   9.80537713e-01,
#           6.84500788e-04,   2.90335879e-06,   4.55926463e-04,
#           1.05019799e-03],
#        [  2.92178821e-02,   9.51025228e-04,   1.47292260e-02,
#           8.22550093e-04,   2.38334965e-02,   7.18917370e-01,
#           3.64156142e-02,   3.21377447e-05,   9.49814767e-02,
#           8.00992250e-02],
#        [  5.62218437e-03,   4.05632163e-04,   4.38825984e-04,
#           4.02701044e-05,   4.61780978e-03,   9.84369278e-01,
#           2.41849688e-03,   2.33071614e-06,   2.67700001e-04,
#           1.81746308e-03],
#        [  1.73967518e-03,   4.04550199e-04,   1.69488264e-03,
#           1.83101438e-04,   4.80254972e-03,   9.36919034e-01,
#           2.40918566e-02,   2.76176047e-06,   2.40349043e-02,
#           6.12664176e-03],
#        [  1.93817995e-03,   5.79762447e-04,   8.24045157e-04,
#           4.54958965e-04,   2.14100610e-02,   9.48088586e-01,
#           8.70303344e-03,   6.67404220e-06,   7.93780480e-03,
#           1.00569054e-02],
#        [  1.29616503e-02,   2.37429794e-03,   7.54641043e-03,
#           4.88397745e-05,   5.07250689e-02,   8.94281864e-01,
#           2.10209750e-02,   9.01547901e-06,   2.12662085e-03,
#           8.90526082e-03],
#        [  1.03211142e-02,   2.24783574e-03,   7.39980210e-03,
#           2.70006771e-04,   1.75248440e-02,   8.76243651e-01,
#           4.80757467e-02,   1.23746986e-05,   3.21934633e-02,
#           5.71129005e-03],
#        [  8.56169872e-03,   1.26416038e-03,   8.47030431e-03,
#           1.51588669e-04,   6.64509321e-03,   9.13433015e-01,
#           1.58628635e-02,   1.14865697e-05,   3.96464765e-02,
#           5.95332356e-03]], dtype=float32)

# %%
err = 100.0 - (100.0 * np.sum(np.argmax(predictions, 1) == data['test_y'][0:64,...]) / predictions.shape[0])

# %%
err
# Out:
# 89.0625

# %%
data['test_y'][0]
# Out:
# 7

# %%
p = predictions[0]

# %%
p
# Out:
# array([  1.56828179e-03,   1.59118243e-03,   1.18014391e-03,
#          2.05317585e-04,   5.52182365e-03,   9.79473054e-01,
#          1.98715413e-03,   9.70758902e-06,   6.65921252e-03,
#          1.80409849e-03], dtype=float32)

# %%
np.sum(np.argmax(p) == data['test_y'][0])
# Out:
# 0
